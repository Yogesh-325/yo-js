# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogesh-325/yo-js/blob/main/Day_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!!")
# Out:
# hello world!!

# %%
name = input("enter your name : ")
print ("Hello, ", name, "! Welcome!")
# Out:
# enter your name : yogi
# Hello,  yogi ! Welcome!

# %%
s = "Bob"
print(s)

s = "Alice"
age = 25
city = "New York"
print(s, age, city)
# Out:
# Bob
# Alice 25 New York

# %%
x, y = input("Enter two values: ").split()
print("Number of boys: ", x)
print("Number of girls: ", y)

x, y, z = input("Enter three values: ").split()
print("First number: ", x)
print("Second number: ", y)
print("Third number: ", z)
# Out:
# Enter two values: 33 54
# Number of boys:  33
# Number of girls:  54
# Enter three values: 32
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1596603713.py in <cell line: 0>()
#       3 print("Number of girls: ", y)
#       4
# ----> 5 x, y, z = input("Enter three values: ").split()
#       6 print("First number: ", x)
#       7 print("Second number: ", y)
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
#change the type of input

#taking input as a string
color = input("What is the color of rose?: ")
print(color)

#taking input as int
#typecasting to int
n = int(input("How many roses do you want in bffe?: "))
print(n)

#taking input as float
#Typecasting to float
price = float(input("Price of each rose?: "))
print(price)
# Out:
# What is the color of rose?: green
# green
# How many roses do you want in bffe?: 33
# 33
# Price of each rose?: 345.3
# 345.3

# %%
#find Datatypes of input in python
a = "Hello World"
b = 10
c = 11.33
d = ("geeks", "for", "geeks")
e = ["Geeks", "for", "Geeks"]
f = {"Geeks": 1, "for": 2, "Geeks": 3}

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'tuple'>
# <class 'list'>
# <class 'dict'>

# %% [markdown]
# ## Python Variables

# %%
x = 5
name = "Samantha"

print(x)
print(name)

age = 21
_color = "lilac"
total_score = 90

print(age)
print(_color)
print(total_score)

#invalid :starta with digits: 1name = "Error" , reserved keywords: class = 10, contain a hyphen : user-name = "Yogi"


x = "Now x is a string"
print(type(x))

# multiple assignments

a = b = c = 100
print(a,b,c)

# assigning different Values
i, j, k = 1, 2.4, "yogi bhai"
print(i,j,k)
# Out:
# 5
# Samantha
# 21
# lilac
# 90
# <class 'str'>
# 100 100 100
# 1 2.4 yogi bhai

# %%
# typecasting a variable

s = "10"
n = int(s)

cnt = 5
f = float(cnt)

age = 25
s2 = str(age)

print(s, n, cnt, f, age, s2)

print(type(s))
print(type(n))
print(type(cnt))
print(type(f))
print(type(age))
print(type(s2))
# Out:
# 10 10 5 5.0 25 25
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
x = 10
print(x)

del x
# print(x) #this will give us name error because 'x' is not defined
# Out:
# 10

# %% [markdown]
# Swapping two Variable

# %%
a, b = 5, 10
a, b = b, a
print(a, b)
# Out:
# 10 5

# %% [markdown]
# counting characters in a string

# %%
word = "Python"
length = len(word)

print("Length of the word:", length)
# Out:
# Length of the word: 6

# %% [markdown]
# Python Keywords

# %%
import keyword

print("The list of keywords is : ")
print(keyword.kwlist)
# Out:
# The list of keywords is :
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
for = 10
# print(for) # this also gives SyntaxError: invalid syntax
# Out:
#   File "/tmp/ipython-input-3359357732.py", line 1
#     for = 10
#         ^
# SyntaxError: invalid syntax
